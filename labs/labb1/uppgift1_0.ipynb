# %%
# Uppgift 1)

import pandas as pd
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors
from fuzzywuzzy import process 


movies = "../../data/ml-latest-small/movies.csv"
ratings = "../../data/ml-latest-small/ratings.csv"

df_movies = pd.read_csv(movies, usecols = ["movieId", "title"], dtype = {"movieId":"int32", "title":"str"})
df_ratings = pd.read_csv(ratings, usecols = ["userId","movieId","rating"], dtype = {"userId":"int32", "movieId":"int32", "rating":"float32"})

# %%
#Spare Matrix

movies_users = df_ratings.pivot(index = "movieId", columns = "userId", values = "rating").fillna(0)
mat_movies_users = csr_matrix(movies_users.values)

# %%
# Euclidean Distance
# Manhattan Distance
# Minkowski Distance
# Cosine Similarity

model_knn = NearestNeighbors(metric = "euclidean", algorithm="brute", n_neighbors=20)

# %%
model_knn.fit(mat_movies_users)
# Out:
# NearestNeighbors(algorithm='brute', metric='euclidean', n_neighbors=20)

# %%
# Recommender(movies_name) => List of Movies recommended

def recommender(movie_name, data, model, n_recommendations ):
    model.fit(data)
    idx=process.extractOne(movie_name, df_movies["title"])[2]
    print("Movie Selected: ",df_movies["title"][idx], "Index:", idx )
    print ("Searching for recommendations...")
    distances, indices=model.kneighbors(data[idx], n_neighbors=n_recommendations)
    for i in indices:
        print(df_movies["title"][i].where(i!=idx))
        
recommender("star wars", mat_movies_users, model_knn,20)
# Out:
# Movie Selected:  Star Wars: Episode IV - A New Hope (1977) Index: 224
# Searching for recommendations...
# 224                                                   NaN
# 897                 Cheech and Chong's Up in Smoke (1978)
# 910     Once Upon a Time in the West (C'era una volta ...
# 899                            Princess Bride, The (1987)
# 989                         Some Kind of Wonderful (1987)
# 1978                          Black Mask (Hak hap) (1996)
# 968                           Arsenic and Old Lace (1944)
# 938                                     Local Hero (1983)
# 1575                                Outsiders, The (1983)
# 615                  Independence Day (a.k.a. ID4) (1996)
# 1182                                          Fall (1997)
# 963                                           Diva (1981)
# 901                                         Brazil (1985)
# 1938                           Walk on the Moon, A (1999)
# 898     Star Wars: Episode V - The Empire Strikes Back...
# 2037                                   Lake Placid (1999)
# 914                                     Goodfellas (1990)
# 2832                               Pawnbroker, The (1964)
# 1502                          Jane Austen's Mafia! (1998)
# 793                                       Die Hard (1988)
# Name: title, dtype: object

# %%
# Uppgift 1)

import pandas as pd
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors
from fuzzywuzzy import process 


movies = "../../data/ml-latest-small/movies.csv"
ratings = "../../data/ml-latest-small/ratings.csv"

df_movies = pd.read_csv(movies, usecols = ["movieId", "title"], dtype = {"movieId":"int32", "title":"str"})
df_ratings = pd.read_csv(ratings, usecols = ["userId","movieId","rating"], dtype = {"userId":"int32", "movieId":"int32", "rating":"float32"})

#Spare Matrix

movies_users = df_ratings.pivot(index = "movieId", columns = "userId", values = "rating").fillna(0)
mat_movies_users = csr_matrix(movies_users.values)
model_knn = NearestNeighbors(metric = "euclidean", algorithm="brute", n_neighbors=20)
def recommender(movie_name, data, model, n_recommendations ):
    model.fit(data)
    idx=process.extractOne(movie_name, df_movies["title"])[2]
    print("Movie Selected: ",df_movies["title"][idx], "Index:", idx )
    print ("Searching for recommendations...")
    distances, indices=model.kneighbors(data[idx], n_neighbors=n_recommendations)
    for i in indices:
        print(df_movies["title"][i].where(i!=idx))
        
recommender("star wars", mat_movies_users, model_knn,20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\lager\Documents\Github\AI-Bjorn-Lagerblad-OPA23\venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rating'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 33
#      30     for i in indices:
#      31         print(df_movies["title"][i].where(i!=idx))
# ---> 33 recommender("star wars", mat_movies_users, model_knn,20)
#
# Cell In[2], line 27, in recommender(movie_name, data, model, n_recommendations)
#      25 model.fit(data)
#      26 idx=process.extractOne(movie_name, df_movies["title"])[2]
# ---> 27 print("Movie Selected: ",df_movies["rating"][idx], "Index:", idx )
#      28 print ("Searching for recommendations...")
#      29 distances, indices=model.kneighbors(data[idx], n_neighbors=n_recommendations)
#
# File c:\Users\lager\Documents\Github\AI-Bjorn-Lagerblad-OPA23\venv\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File c:\Users\lager\Documents\Github\AI-Bjorn-Lagerblad-OPA23\venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'rating'
